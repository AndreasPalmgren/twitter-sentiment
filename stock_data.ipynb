# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
sp500 = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
sp500 = sp500[0]

# %%
sp500
# Out:
#     Symbol       Security SEC filings             GICS Sector  \
# 0      MMM             3M     reports             Industrials
# 1      AOS    A. O. Smith     reports             Industrials
# 2      ABT         Abbott     reports             Health Care
# 3     ABBV         AbbVie     reports             Health Care
# 4     ABMD        Abiomed     reports             Health Care
# ..     ...            ...         ...                     ...
# 499    YUM    Yum! Brands     reports  Consumer Discretionary
# 500   ZBRA          Zebra     reports  Information Technology
# 501    ZBH  Zimmer Biomet     reports             Health Care
# 502   ZION  Zions Bancorp     reports              Financials
# 503    ZTS         Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# 1                     Building Products     Milwaukee, Wisconsin
# ...

# %%
dt = yf.download(sp500["Symbol"].to_list(), "2021-03-01", "2022-04-30")
# Out:
# [*********************100%***********************]  504 of 504 completed
#
# 2 Failed downloads:
# - BRK.B: No data found, symbol may be delisted
# - BF.B: No data found for this date range, symbol may be delisted

# %%
type(dt)
# Out:
# pandas.core.frame.DataFrame

# %%
dt.pct_change()
# Out:
#            Adj Close                                                    \
#                    A       AAL       AAP      AAPL      ABBV       ABC
# Date
# 2021-03-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-03-02 -0.006748  0.012276  0.013402 -0.020894 -0.005166  0.010468
# 2021-03-03 -0.035102  0.034048  0.006006 -0.024457 -0.010570 -0.008729
# 2021-03-04 -0.036127 -0.041949 -0.001749 -0.015812 -0.009933 -0.003387
# 2021-03-05  0.010001 -0.037194  0.036064  0.010738  0.009939  0.017866
# ...              ...       ...       ...       ...       ...       ...
# 2022-04-25  0.001072 -0.009911  0.025093  0.006737  0.008452 -0.003333
# 2022-04-26 -0.028901 -0.060561 -0.001921 -0.037328 -0.000768 -0.007699
# 2022-04-27 -0.002205  0.010655  0.006445 -0.001467  0.009220  0.001335
# 2022-04-28  0.028722  0.024249 -0.068881  0.045155 -0.008311  0.001842
# 2022-04-29 -0.014786 -0.033968 -0.046612 -0.036605 -0.060329 -0.040951
#
# ...

# %%
df_gspc = yf.download("^GSPC", "2022-03-14", "2022-04-15")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_gspc["Close"].pct_change()
# Out:
# Date
# 2022-03-14         NaN
# 2022-03-15    0.021409
# 2022-03-16    0.022384
# 2022-03-17    0.012348
# 2022-03-18    0.011662
# 2022-03-21   -0.000435
# 2022-03-22    0.011304
# 2022-03-23   -0.012273
# 2022-03-24    0.014344
# 2022-03-25    0.005066
# 2022-03-28    0.007145
# 2022-03-29    0.012257
# 2022-03-30   -0.006294
# 2022-03-31   -0.015653
# 2022-04-01    0.003410
# 2022-04-04    0.008091
# 2022-04-05   -0.012552
# 2022-04-06   -0.009717
# 2022-04-07    0.004253
# 2022-04-08   -0.002651
# 2022-04-11   -0.016877
# 2022-04-12   -0.003417
# 2022-04-13    0.011175
# 2022-04-14   -0.012144
# Name: Close, dtype: float64

# %%
rc = {
        "axes.spines.left" : True,
        "axes.spines.right" : False,
        "axes.spines.bottom" : True,
        "axes.spines.top" : False,
        "xtick.bottom" : True,
        "xtick.labelbottom" : True,
        "ytick.labelleft" : True,
        "ytick.left" : True,
        "figure.subplot.hspace" : 0.7,
        "figure.titleweight" : "bold",
        "axes.titleweight" : "bold"
    }

plt.rcParams.update(rc)

# %%
fig, axs = plt.subplots(1, figsize=(15, 12))

axs.plot(df_gspc["Close"])
plt.savefig("gspc.png")
